# %% [markdown]
# ## Imports:

# %%
import pickle
import tensorflow
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## loading database:

# %%
with open('pre_processed_census_database.pkl', mode='rb') as f:
    X_training, y_training, X_test, y_test, X_scaler = pickle.load(f)

# %%
X_training.shape, y_training.shape, X_test.shape, y_test.shape
# Out:
# ((25637, 108), (25637,), (4525, 108), (4525,))

# %%
X_training
# Out:
# array([[-0.24923292,  5.7990656 , -0.2618232 , ..., -0.14945152,
#         -0.21178197,  1.56608846],
#        [-0.24923292, -0.17244157, -0.2618232 , ..., -0.14945152,
#         -0.21178197, -0.02660563],
#        [-0.24923292, -0.17244157,  3.81937127, ..., -0.14945152,
#         -0.21178197, -0.42477915],
#        ...,
#        [-0.24923292, -0.17244157, -0.2618232 , ..., -0.14945152,
#         -0.21178197, -0.02660563],
#        [-0.24923292, -0.17244157, -0.2618232 , ..., -0.14945152,
#         -0.21178197, -0.02660563],
#        [-0.24923292, -0.17244157, -0.2618232 , ..., -0.14945152,
#         -0.21178197, -0.82295267]])

# %%
y_training
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %% [markdown]
# ## Training

# %% [markdown]
# ### Model

# %%
model = keras.Sequential([
    keras.layers.Dense(108, activation=tensorflow.nn.relu),
    keras.layers.Dense(64, activation=tensorflow.nn.relu),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(32, activation=tensorflow.nn.relu),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(2, activation=tensorflow.nn.softmax)
])

# %% [markdown]
# ### Hyperparameters

# %%
adam = keras.optimizers.Adam(learning_rate=0.0001)

callbacks = [
    keras.callbacks.EarlyStopping('val_loss'), 
    keras.callbacks.EarlyStopping('val_accuracy')
]

# %% [markdown]
# ### Compile

# %%
model.compile(optimizer=adam, 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

history = model.fit(X_training, y_training, 
                    batch_size=56,
                    epochs=30, 
                    validation_split=0.2, 
                    callbacks=callbacks)
# Out:
# Epoch 1/30
# 367/367 [==============================] - 2s 3ms/step - loss: 0.5418 - accuracy: 0.7326 - val_loss: 0.4160 - val_accuracy: 0.8130
# Epoch 2/30
# 367/367 [==============================] - 1s 2ms/step - loss: 0.4091 - accuracy: 0.8117 - val_loss: 0.3727 - val_accuracy: 0.8286
# Epoch 3/30
# 367/367 [==============================] - 1s 2ms/step - loss: 0.3777 - accuracy: 0.8271 - val_loss: 0.3581 - val_accuracy: 0.8346
# Epoch 4/30
# 367/367 [==============================] - 1s 2ms/step - loss: 0.3634 - accuracy: 0.8321 - val_loss: 0.3516 - val_accuracy: 0.8370
# Epoch 5/30
# 367/367 [==============================] - 1s 2ms/step - loss: 0.3527 - accuracy: 0.8366 - val_loss: 0.3457 - val_accuracy: 0.8413
# Epoch 6/30
# 367/367 [==============================] - 1s 2ms/step - loss: 0.3467 - accuracy: 0.8395 - val_loss: 0.3414 - val_accuracy: 0.8424
# Epoch 7/30
# 367/367 [==============================] - 1s 2ms/step - loss: 0.3407 - accuracy: 0.8413 - val_loss: 0.3402 - val_accuracy: 0.8442
# Epoch 8/30
# 367/367 [==============================] - 1s 2ms/step - loss: 0.3345 - accuracy: 0.8437 - val_loss: 0.3357 - val_accuracy: 0.8438

# %% [markdown]
# ## Visualizing training and validation:

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Accuracy for epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Training', 'Evaluation'])
plt.show()

# %% [markdown]
# ## Visualizing losses and validation:

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss for epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Training', 'Evaluation'])
plt.show()

# %% [markdown]
# ## Evaluating the model with the test base:
# ### Accuracy and Loss

# %%
loss_test, accuracy_test = model.evaluate(X_test, y_test)
print(f'\nLOSS: >>>>> {loss_test}')
print(f'\nACCURACY: >>>>> {accuracy_test}')
# Out:
# 142/142 [==============================] - 0s 1ms/step - loss: 0.3325 - accuracy: 0.8480
#
# LOSS: >>>>> 0.3325318694114685
#
# ACCURACY: >>>>> 0.8479558229446411

# %% [markdown]
# ## Testing with test dataset

# %%
test_data = model.predict(X_test)
prediction = np.argmax(test_data[0])
pred_true = y_test[0]
# Out:
# 142/142 [==============================] - 0s 982us/step

# %%
if prediction == 0:
    print('Pediction: >>> Annual income less than or equal to 50 >>>(<=50k)')
else:
    print('Pediction: >>> Annual income greater than 50k >>>(>50k)')
if pred_true == 0:
    print('Pred_True: >>> Annual income less than or equal to 50 >>>(<=50k)')
else:
    print('Pred_True: >>> Annual income greater than 50k >>>(>50k)')
# Out:
# Pediction: >>> Annual income less than or equal to 50 >>>(<=50k)
# Pred_True: >>> Annual income less than or equal to 50 >>>(<=50k)

# %% [markdown]
# ## Saving model:

# %%
model.save('model.keras')
